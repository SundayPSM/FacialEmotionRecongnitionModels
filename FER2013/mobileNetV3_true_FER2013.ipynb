# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Fri Nov 11 14:17:30 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   29C    P0    50W / 400W |   3472MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install MTCNN
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting MTCNN
#   Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 14.3 MB/s
# Requirement already satisfied: opencv-python>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from MTCNN) (4.6.0.66)
# Requirement already satisfied: keras>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from MTCNN) (2.9.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python>=4.1.0->MTCNN) (1.21.6)
# Installing collected packages: MTCNN
# Successfully installed MTCNN-0.1.1

# %%
# !unzip "/content/drive/MyDrive/Research/Cropped_FER_2013.zip"

# %%
# !cp -r Cropped_FER_2013 "/content/drive/MyDrive/Research/"

# %%
pwd
# Out:
# '/content'

# %%
from mtcnn import MTCNN
import cv2
import os, glob
import numpy as np
# from tqdm import tqdm_notebook
from tqdm.notebook import tqdm_notebook
import shutil
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import keras
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
base_model = keras.applications.MobileNetV3Large(
    weights = 'imagenet',  # Load weights pre-trained on ImageNet.
    input_shape = (224, 224, 3),
    include_top = False,
    classifier_activation = "softmax",
    classes = 7
) 

base_model.trainable = True

# inputs = keras.Input(shape=(224, 224, 3))
inputs = keras.Input(shape=(224, 224, 3))

x = base_model(inputs, training=True)
x = keras.layers.GlobalAveragePooling2D()(x)
outputs = keras.layers.Dense(7, activation="softmax")(x)

model = keras.Model(inputs, outputs)

# %%
path="/content/drive/MyDrive/Research/Cropped_FER_2013/train"

# dataset = keras.preprocessing.image_dataset_from_directory(path, image_size=(224, 224), label_mode="categorical")
train_dataset = keras.preprocessing.image_dataset_from_directory(path, image_size=(224, 224), label_mode="categorical", validation_split=0.3, subset="training", seed=42)
valid_dataset = keras.preprocessing.image_dataset_from_directory(path, image_size=(224, 224), label_mode="categorical", validation_split=0.3, subset="validation", seed=42)
# Out:
# Found 23380 files belonging to 7 classes.
# Using 16366 files for training.
# Found 23380 files belonging to 7 classes.
# Using 7014 files for validation.

# %%
model.compile(optimizer=keras.optimizers.Adam(),
              loss="categorical_crossentropy",
              metrics=["accuracy"])
# model.fit(dataset, epochs=20, validation_split=0.2)
history = model.fit(train_dataset, epochs=30, validation_data=valid_dataset)
# Out:
# Epoch 1/30
# 512/512 [==============================] - 82s 145ms/step - loss: 1.1663 - accuracy: 0.5615 - val_loss: 0.9997 - val_accuracy: 0.6285
# Epoch 2/30
# 512/512 [==============================] - 73s 142ms/step - loss: 0.9047 - accuracy: 0.6611 - val_loss: 1.0294 - val_accuracy: 0.6280
# Epoch 3/30
# 512/512 [==============================] - 72s 141ms/step - loss: 0.7636 - accuracy: 0.7143 - val_loss: 1.0810 - val_accuracy: 0.6212
# Epoch 4/30
# 512/512 [==============================] - 72s 141ms/step - loss: 0.6331 - accuracy: 0.7670 - val_loss: 1.1482 - val_accuracy: 0.6176
# Epoch 5/30
# 512/512 [==============================] - 72s 141ms/step - loss: 0.5064 - accuracy: 0.8127 - val_loss: 1.2704 - val_accuracy: 0.6235
# Epoch 6/30
# 512/512 [==============================] - 73s 142ms/step - loss: 0.4046 - accuracy: 0.8534 - val_loss: 1.3638 - val_accuracy: 0.6259
# Epoch 7/30
# 512/512 [==============================] - 73s 141ms/step - loss: 0.3354 - accuracy: 0.8749 - val_loss: 1.4561 - val_accuracy: 0.6290
# Epoch 8/30
# 512/512 [==============================] - 73s 142ms/step - loss: 0.2806 - accuracy: 0.9008 - val_loss: 1.5377 - val_accuracy: 0.6389
# Epoch 9/30
# 512/512 [==============================] - 72s 141ms/step - loss: 0.2413 - accuracy: 0.9140 - val_loss: 1.6951 - val_accuracy: 0.6240
# Epoch 10/30
# 512/512 [==============================] - 73s 143ms/step - loss: 0.2075 - accuracy: 0.9273 - val_loss: 1.6395 - val_accuracy: 0.6339
# Epoch 11/30
# 512/512 [==============================] - 73s 143ms/step - loss: 0.1916 - accuracy: 0.9325 - val_loss: 1.7482 - val_accuracy: 0.6370
# Epoch 12/30
# 512/512 [==============================] - 72s 141ms/step - loss: 0.1684 - accuracy: 0.9394 - val_loss: 1.8388 - val_accuracy: 0.6376
# Epoch 13/30
# 512/512 [==============================] - 72s 141ms/step - loss: 0.1561 - accuracy: 0.9466 - val_loss: 1.8161 - val_accuracy: 0.6437
# Epoch 14/30
# 512/512 [==============================] - 72s 141ms/step - loss: 0.1421 - accuracy: 0.9509 - val_loss: 1.9178 - val_accuracy: 0.6430
# Epoch 15/30
# 512/512 [==============================] - 73s 142ms/step - loss: 0.1363 - accuracy: 0.9528 - val_loss: 1.8091 - val_accuracy: 0.6350
# Epoch 16/30
# 512/512 [==============================] - 73s 142ms/step - loss: 0.1339 - accuracy: 0.9511 - val_loss: 1.8925 - val_accuracy: 0.6359
# Epoch 17/30
# 512/512 [==============================] - 73s 142ms/step - loss: 0.1279 - accuracy: 0.9539 - val_loss: 1.8255 - val_accuracy: 0.6336
# Epoch 18/30
# 512/512 [==============================] - 73s 142ms/step - loss: 0.1329 - accuracy: 0.9546 - val_loss: 1.8269 - val_accuracy: 0.6497
# Epoch 19/30
# 512/512 [==============================] - 73s 142ms/step - loss: 0.1105 - accuracy: 0.9603 - val_loss: 1.9193 - val_accuracy: 0.6424
# Epoch 20/30
# 512/512 [==============================] - 73s 142ms/step - loss: 0.1038 - accuracy: 0.9652 - val_loss: 1.9740 - val_accuracy: 0.6387
# Epoch 21/30
# 512/512 [==============================] - 73s 141ms/step - loss: 0.1046 - accuracy: 0.9638 - val_loss: 1.9156 - val_accuracy: 0.6382
# Epoch 22/30
# 512/512 [==============================] - 72s 140ms/step - loss: 0.1130 - accuracy: 0.9620 - val_loss: 2.0064 - val_accuracy: 0.6393
# Epoch 23/30
# 512/512 [==============================] - 72s 140ms/step - loss: 0.1008 - accuracy: 0.9644 - val_loss: 2.0014 - val_accuracy: 0.6508
# Epoch 24/30
# 512/512 [==============================] - 73s 142ms/step - loss: 0.0835 - accuracy: 0.9724 - val_loss: 2.0690 - val_accuracy: 0.6386
# Epoch 25/30
# 512/512 [==============================] - 73s 143ms/step - loss: 0.0930 - accuracy: 0.9685 - val_loss: 1.9815 - val_accuracy: 0.6410
# Epoch 26/30
#  47/512 [=>............................] - ETA: 1:01 - loss: 0.0977 - accuracy: 0.9674

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('MobileNetV3Large_true model accuracy on FER2013')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig('MobileNetV3Large_true_FER2013_model_accuracy.png')
# !cp MobileNetV3Large_true_FER2013_model_accuracy.png "/content/drive/MyDrive/Research/"
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('MobileNetV3Large_true model loss on FER2013')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig('MobileNetV3Large_true_FER2013_model_loss.png')
# !cp MobileNetV3Large_true_FER2013_model_loss.png "/content/drive/MyDrive/Research/"
plt.show()

# %%
print("Training Accuracy ",max(history.history['accuracy']))
print("Testing Accuracy",max(history.history['val_accuracy']))
# Out:
# Training Accuracy  0.9729927778244019
# Testing Accuracy 0.6625320911407471

# %%
#Save the Model 
model.save("MobileNetV3Large_true_FER2013")
# !cp -r MobileNetV3Large_true_FER2013 "/content/drive/MyDrive/Research/"
import tensorflow as tf

# Convert the model
converter = tf.lite.TFLiteConverter.from_saved_model("MobileNetV3Large_true_FER2013") # path to the SavedModel directory
tflite_model = converter.convert()

# Save the model in the .tflite .
with open('MobileNetV3Large_true_FER2013.tflite', 'wb') as f:
  f.write(tflite_model)

# copy the .tflite to Drive
# !cp MobileNetV3Large_true_FER2013.tflite "/content/drive/MyDrive/Research/"
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 62). These functions will not be directly callable after loading.
# ---------------------------------------------------------------------------
# ConverterError                            Traceback (most recent call last)
# <ipython-input-30-7c00bde7a4ac> in <module>
#       6 # Convert the model
#       7 converter = tf.lite.TFLiteConverter.from_saved_model("MobileNetV3Large_true_FER2013") # path to the SavedModel directory
# ----> 8 tflite_model = converter.convert()
#       9
#      10 # Save the model in the .tflite .
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/lite/python/lite.py in wrapper(self, *args, **kwargs)
#     927   def wrapper(self, *args, **kwargs):
#     928     # pylint: disable=protected-access
# --> 929     return self._convert_and_export_metrics(convert_func, *args, **kwargs)
#     930     # pylint: enable=protected-access
#     931
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/lite/python/lite.py in _convert_and_export_metrics(self, convert_func, *args, **kwargs)
#     906     self._save_conversion_params_metric()
#     907     start_time = time.process_time()
# --> 908     result = convert_func(self, *args, **kwargs)
#     909     elapsed_time_ms = (time.process_time() - start_time) * 1000
#     910     if result:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/lite/python/lite.py in convert(self)
#    1210           graph_def)
#    1211
# -> 1212     return self._convert_from_saved_model(graph_def)
#    1213
#    1214
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/lite/python/lite.py in _convert_from_saved_model(self, graph_def)
#    1093     converter_kwargs.update(quant_mode.converter_flags())
#    1094
# -> 1095     result = _convert_saved_model(**converter_kwargs)
#    1096     return self._optimize_tflite_model(
#    1097         result, quant_mode, quant_io=self.experimental_new_quantizer)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/lite/python/convert_phase.py in wrapper(*args, **kwargs)
#     210         else:
#     211           report_error_message(str(converter_error))
# --> 212         raise converter_error from None  # Re-throws the exception.
#     213       except Exception as error:
#     214         report_error_message(str(error))
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/lite/python/convert_phase.py in wrapper(*args, **kwargs)
#     203     def wrapper(*args, **kwargs):
#     204       try:
# --> 205         return func(*args, **kwargs)
#     206       except ConverterError as converter_error:
#     207         if converter_error.errors:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/lite/python/convert.py in convert_saved_model(**kwargs)
#     812       input_data_str=None,
#     813       debug_info_str=None,
# --> 814       enable_mlir_converter=True)
#     815   return data
#     816
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/lite/python/convert.py in convert(model_flags_str, conversion_flags_str, input_data_str, debug_info_str, enable_mlir_converter)
#     309       for error_data in _metrics_wrapper.retrieve_collected_errors():
#     310         converter_error.append_error(error_data)
# --> 311       raise converter_error
#     312
#     313   return _run_deprecated_conversion_binary(model_flags_str,
#
# ConverterError: <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/Conv/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/Conv/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_1/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_1/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_1/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_1/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_1/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_1/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_2/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_2/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_2/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_2/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_2/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_2/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_3/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_3/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_3/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_3/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_3/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_3/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_4/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_4/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_4/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_4/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_4/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_4/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_5/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_5/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_5/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_5/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_5/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_5/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_6/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_6/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_6/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_6/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_6/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_6/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_7/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_7/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_7/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_7/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_7/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_7/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_8/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_8/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_8/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_8/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_8/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_8/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_9/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_9/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_9/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_9/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_9/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_9/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_10/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_10/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_10/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_10/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_10/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_10/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_11/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_11/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_11/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_11/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_11/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_11/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_12/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_12/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_12/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_12/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_12/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_12/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_13/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_13/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_13/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_13/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_13/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_13/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_14/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_14/expand/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_14/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_14/depthwise/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_14/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/expanded_conv_14/project/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/Conv_1/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): 'tf.FusedBatchNormV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["FusedBatchNormV3:", "model_2/MobilenetV3large/Conv_1/BatchNorm/FusedBatchNormV3@__inference__wrapped_model_368555"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper_384220"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: failed while converting: 'main':
# Some ops are not supported by the native TFLite runtime, you can enable TF kernels fallback using TF Select. See instructions: https://www.tensorflow.org/lite/guide/ops_select
# TF Select ops: FusedBatchNormV3
# Details:
# 	tf.FusedBatchNormV3(tensor<?x112x112x16xf32>, tensor<16xf32>, tensor<16xf32>, tensor<16xf32>, tensor<16xf32>) -> (tensor<?x112x112x16xf32>, tensor<16xf32>, tensor<16xf32>, tensor<16xf32>, tensor<16xf32>, tensor<*xf32>) : {data_format = "NHWC", device = "", epsilon = 1.000000e-03 : f32, exponential_avg_factor = 1.000000e-03 : f32, is_training = true}
# 	tf.FusedBatchNormV3(tensor<?x112x112x64xf32>, tensor<64xf32>, tensor<64xf32>, tensor<64xf32>, tensor<64xf32>) -> (tensor<?x112x112x64xf32>, tensor<64xf32>, tensor<64xf32>, tensor<64xf32>, tensor<64xf32>, tensor<*xf32>) : {data_format = "NHWC", device = "", epsilon = 1.000000e-03 : f32, exponential_avg_factor = 1.000000e-03 : f32, is_training = true}
# 	tf.FusedBatchNormV3(tensor<?x14x14x112xf32>, tensor<112xf32>, tensor<112xf32>, tensor<112xf32>, tensor<112xf32>) -> (tensor<?x14x14x112xf32>, tensor<112xf32>, tensor<112xf32>, tensor<112xf32>, tensor<112xf32>, tensor<*xf32>) : {data_format = "NHWC", device = "", epsilon = 1.000000e-03 : f32, exponential_avg_factor = 1.000000e-03 : f32, is_training = true}
# 	tf.FusedBatchNormV3(tensor<?x14x14x184xf32>, tensor<184xf32>, tensor<184xf32>, tensor<184xf32>, tensor<184xf32>) -> (tensor<?x14x14x184xf32>, tensor<184xf32>, tensor<184xf32>, tensor<184xf32>, tensor<184xf32>, tensor<*xf32>) : {data_format = "NHWC", device = "", epsilon = 1.000000e-03 : f32, exponential_avg_factor = 1.000000e-03 : f32, is_training = true}
# 	tf.FusedBatchNormV3(tensor<?x14x14x200xf32>, tensor<200xf32>, tensor<200xf32>, tensor<200xf32>, tensor<200xf32>) -> (tensor<?x14x14x200xf32>, tensor<200xf32>, tensor<200xf32>, tensor<200xf32>, tensor<200xf32>, tensor<*xf32>) : {data_format = "NHWC", device = "", epsilon = 1.000000e-03 : f32, exponential_avg_factor = 1.000000e-03 : f32, is_training = true}
# 	tf.FusedBatchNormV3(tensor<?x14x14x240xf32>, tensor<240xf32>, tensor<240xf32>, tensor<240xf32>, tensor<240xf32>) -> (tensor<?x14x14x240xf32>, tensor<240xf32>, tensor<240xf32>, tensor<240xf32>, tensor<240xf32>, tensor<*xf32>) : {data_format = "NHWC", device = "", epsilon = 1.000000e-03 : f32, exponential_avg_factor = 1.000000e-03 : f32, is_training = true}
# 	tf.FusedBatchNormV3(tensor<?x14x14x480xf32>, tensor<480xf32>, tensor<480xf32>, tensor<480xf32>, tensor<480xf32>) -> (tensor<?x14x14x480xf32>, tensor<480xf32>, tensor<480xf32>, tensor<480xf32>, tensor<480xf32>, tensor<*xf32>) : {data_format = "NHWC", device = "", epsilon = 1.000000e-03 : f32, exponential_avg_factor = 1.000000e-03 : f32, is_training = true}
# 	tf.FusedBatchNormV3(tensor<?x14x14x672xf32>, tensor<672xf32>, tensor<672xf32>, tensor<672xf32>, tensor<672xf32>) -> (tensor<?x14x14x672xf32>, tensor<672xf32>, tensor<672xf32>, tensor<672xf32>, tensor<672xf32>, tensor<*xf32>) : {data_format = "NHWC", device = "", epsilon = 1.000000e-03 : f32, exponential_avg_factor = 1.000000e-03 : f32, is_training = true}
# 	tf.FusedBatchNormV3(tensor<?x14x14x80xf32>, tensor<80xf32>, tensor<80xf32>, tensor<80xf32>, tensor<80xf32>) -> (tensor<?x14x14x80xf32>, tensor<80xf32>, tensor<80xf32>, tensor<80xf32>, tensor<80xf32>, tensor<*xf32>) : {data_format = "NHWC", device = "", epsilon = 1.000000e-03 : f32, exponential_avg_factor = 1.000000e-03 : f32, is_training = true}
# 	tf.FusedBatchNormV3(tensor<?x28x28x120xf32>, tensor<120xf32>, tensor<120xf32>, tensor<120xf32>, tensor<120xf32>) -> (tensor<?x28x28x120xf32>, tensor<120xf32>, tensor<120xf32>, tensor<120xf32>, tensor<120xf32>, tensor<*xf32>) : {data_format = "NHWC", device = "", epsilon = 1.000000e-03 : f32, exponential_avg_factor = 1.000000e-03 : f32, is_training = true}
# 	tf.FusedBatchNormV3(tensor<?x28x28x240xf32>, tensor<240xf32>, tensor<240xf32>, tensor<240xf32>, tensor<240xf32>) -> (tensor<?x28x28x240xf32>, tensor<240xf32>, tensor<240xf32>, tensor<240xf32>, tensor<240xf32>, tensor<*xf32>) : {data_format = "NHWC", device = "", epsilon = 1.000000e-03 : f32, exponential_avg_factor = 1.000000e-03 : f32, is_training = true}
# 	tf.FusedBatchNormV3(tensor<?x28x28x40xf32>, tensor<40xf32>, tensor<40xf32>, tensor<40xf32>, tensor<40xf32>) -> (tensor<?x28x28x40xf32>, tensor<40xf32>, tensor<40xf32>, tensor<40xf32>, tensor<40xf32>, tensor<*xf32>) : {data_format = "NHWC", device = "", epsilon = 1.000000e-03 : f32, exponential_avg_factor = 1.000000e-03 : f32, is_training = true}
# 	tf.FusedBatchNormV3(tensor<?x28x28x72xf32>, tensor<72xf32>, tensor<72xf32>, tensor<72xf32>, tensor<72xf32>) -> (tensor<?x28x28x72xf32>, tensor<72xf32>, tensor<72xf32>, tensor<72xf32>, tensor<72xf32>, tensor<*xf32>) : {data_format = "NHWC", device = "", epsilon = 1.000000e-03 : f32, exponential_avg_factor = 1.000000e-03 : f32, is_training = true}
# 	tf.FusedBatchNormV3(tensor<?x56x56x24xf32>, tensor<24xf32>, tensor<24xf32>, tensor<24xf32>, tensor<24xf32>) -> (tensor<?x56x56x24xf32>, tensor<24xf32>, tensor<24xf32>, tensor<24xf32>, tensor<24xf32>, tensor<*xf32>) : {data_format = "NHWC", device = "", epsilon = 1.000000e-03 : f32, exponential_avg_factor = 1.000000e-03 : f32, is_training = true}
# 	tf.FusedBatchNormV3(tensor<?x56x56x64xf32>, tensor<64xf32>, tensor<64xf32>, tensor<64xf32>, tensor<64xf32>) -> (tensor<?x56x56x64xf32>, tensor<64xf32>, tensor<64xf32>, tensor<64xf32>, tensor<64xf32>, tensor<*xf32>) : {data_format = "NHWC", device = "", epsilon = 1.000000e-03 : f32, exponential_avg_factor = 1.000000e-03 : f32, is_training = true}
# 	tf.FusedBatchNormV3(tensor<?x56x56x72xf32>, tensor<72xf32>, tensor<72xf32>, tensor<72xf32>, tensor<72xf32>) -> (tensor<?x56x56x72xf32>, tensor<72xf32>, tensor<72xf32>, tensor<72xf32>, tensor<72xf32>, tensor<*xf32>) : {data_format = "NHWC", device = "", epsilon = 1.000000e-03 : f32, exponential_avg_factor = 1.000000e-03 : f32, is_training = true}
# 	tf.FusedBatchNormV3(tensor<?x7x7x160xf32>, tensor<160xf32>, tensor<160xf32>, tensor<160xf32>, tensor<160xf32>) -> (tensor<?x7x7x160xf32>, tensor<160xf32>, tensor<160xf32>, tensor<160xf32>, tensor<160xf32>, tensor<*xf32>) : {data_format = "NHWC", device = "", epsilon = 1.000000e-03 : f32, exponential_avg_factor = 1.000000e-03 : f32, is_training = true}
# 	tf.FusedBatchNormV3(tensor<?x7x7x672xf32>, tensor<672xf32>, tensor<672xf32>, tensor<672xf32>, tensor<672xf32>) -> (tensor<?x7x7x672xf32>, tensor<672xf32>, tensor<672xf32>, tensor<672xf32>, tensor<672xf32>, tensor<*xf32>) : {data_format = "NHWC", device = "", epsilon = 1.000000e-03 : f32, exponential_avg_factor = 1.000000e-03 : f32, is_training = true}
# 	tf.FusedBatchNormV3(tensor<?x7x7x960xf32>, tensor<960xf32>, tensor<960xf32>, tensor<960xf32>, tensor<960xf32>) -> (tensor<?x7x7x960xf32>, tensor<960xf32>, tensor<960xf32>, tensor<960xf32>, tensor<960xf32>, tensor<*xf32>) : {data_format = "NHWC", device = "", epsilon = 1.000000e-03 : f32, exponential_avg_factor = 1.000000e-03 : f32, is_training = true}
